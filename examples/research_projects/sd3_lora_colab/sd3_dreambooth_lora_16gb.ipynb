# %% [markdown]
# # Running Stable Diffusion 3 (SD3) DreamBooth LoRA training under 16GB GPU VRAM

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install -q -U git+https://github.com/huggingface/diffusers
# !pip install -q -U \
    transformers \
    accelerate \
    wandb \
    bitsandbytes \
    peft

# %% [markdown]
# As SD3 is gated, before using it with diffusers you first need to go to the [Stable Diffusion 3 Medium Hugging Face page](https://huggingface.co/stabilityai/stable-diffusion-3-medium-diffusers), fill in the form and accept the gate. Once you are in, you need to log in so that your system knows you’ve accepted the gate. Use the command below to log in:

# %%
# !hf auth login

# %% [markdown]
# ## Clone `diffusers`

# %%
# !git clone https://github.com/huggingface/diffusers
# %cd diffusers/examples/research_projects/sd3_lora_colab

# %% [markdown]
# ## Download instance data images

# %%
from huggingface_hub import snapshot_download

local_dir = "./dog"
snapshot_download(
    "diffusers/dog-example",
    local_dir=local_dir, repo_type="dataset",
    ignore_patterns=".gitattributes",
)

# %%
# !rm -rf dog/.cache

# %% [markdown]
# ## Compute embeddings
#
# Here we are using the default instance prompt "a photo of sks dog". But you can configure this. Refer to the `compute_embeddings.py` script for details on other supported arguments.

# %%
# !python compute_embeddings.py

# %% [markdown]
# ## Clear memory

# %%
import torch
import gc


def flush():
    torch.cuda.empty_cache()
    gc.collect()

flush()

# %% [markdown]
# ## Train!

# %%
# !accelerate launch train_dreambooth_lora_sd3_miniature.py \
  --pretrained_model_name_or_path="stabilityai/stable-diffusion-3-medium-diffusers"  \
  --instance_data_dir="dog" \
  --data_df_path="sample_embeddings.parquet" \
  --output_dir="trained-sd3-lora-miniature" \
  --mixed_precision="fp16" \
  --instance_prompt="a photo of sks dog" \
  --resolution=1024 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 --gradient_checkpointing \
  --use_8bit_adam \
  --learning_rate=1e-4 \
  --report_to="wandb" \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=500 \
  --seed="0"
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-12-02 07:01:19.207331: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764658879.227498    7474 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764658879.233555    7474 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764658879.249070    7474 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764658879.249094    7474 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764658879.249100    7474 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764658879.249104    7474 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-02 07:01:19.253695: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# {'use_dynamic_shifting', 'base_shift', 'time_shift_type', 'invert_sigmas', 'stochastic_sampling', 'shift_terminal', 'use_exponential_sigmas', 'max_image_seq_len', 'use_karras_sigmas', 'max_shift', 'base_image_seq_len', 'use_beta_sigmas'} was not found in config. Values will be initialized to default values.
# config.json: 100% 739/739 [00:00<00:00, 5.01MB/s]
# vae/diffusion_pytorch_model.safetensors: 100% 168M/168M [00:02<00:00, 72.8MB/s]
# {'mid_block_add_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at stabilityai/stable-diffusion-3-medium-diffusers.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# config.json: 100% 372/372 [00:00<00:00, 2.56MB/s]
# transformer/diffusion_pytorch_model.safe(…): 100% 4.17G/4.17G [02:21<00:00, 29.5MB/s]
# {'dual_attention_layers', 'qk_norm'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing SD3Transformer2DModel.
#
# All the weights of SD3Transformer2DModel were initialized from the model checkpoint at stabilityai/stable-diffusion-3-medium-diffusers.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use SD3Transformer2DModel for predictions without further training.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Tracking run with wandb version 0.23.0
# wandb: W&B syncing is set to `offline` in this directory. Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# wandb: Run data is saved locally in /content/diffusers/examples/research_projects/sd3_lora_colab/wandb/offline-run-20251202_070605-gpkjrk64
# Steps:  25% 126/500 [19:06<50:25,  8.09s/it, loss=0.0372, lr=0.0001]

# %% [markdown]
# Training will take about an hour to complete depending on the length of your dataset.

# %% [markdown]
# ## Inference

# %%
flush()

# %%
from diffusers import DiffusionPipeline
import torch

pipeline = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-3-medium-diffusers",
    torch_dtype=torch.float16
)
lora_output_path = "trained-sd3-lora-miniature"
pipeline.load_lora_weights("trained-sd3-lora-miniature")

pipeline.enable_sequential_cpu_offload()

image = pipeline("a photo of sks dog in a bucket").images[0]
image.save("bucket_dog.png")

# %% [markdown]
# Note that inference will be very slow in this case because we're loading and unloading individual components of the models and that introduces significant data movement overhead. Refer to [this resource](https://huggingface.co/blog/sd3#memory-optimizations-for-sd3) for more memory optimization related techniques.
